# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def simple_print(y_label,value1_list,value1_label, value2_list, value2_label, step_list):
    print "simple_print"
    fig = plt.figure(figsize=(8, 4))
    ax = fig.add_subplot(111)
    ax.set_xlabel('Gauss Num')
    #ax.set_ylabel(y_label)
    ax.set_ylabel('Time')
    ax.plot(step_list, value1_list, label=value1_label)
    ax.plot(step_list, value2_list, label=value2_label)
    ax.grid('on')
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

filename = "exp_mono_t1.log"
path = "/Users/xuziqiang/Edinburgh/ASR/AutoSpchRcgntion/"
logfile = path+filename
with open(logfile, "r") as ins:
    loglist = []
    for line in ins:
        loglist.append(line)


import re
gauss_lst = []
wer_lst = []
train_time_lst = []
eval_time_lst = []

for i in loglist:
      gauss = re.match(r".*testing.*" ,i)
      wer = re.match(r"\%WER.*", i)
      train_time = re.match(r".*training.*", i)
      eval_time = re.match(r".*evaluation.*", i)
      if gauss:
          gauss_num = re.match(r".*testing gaussian number (\d+) <<", i)
          #print gauss_num.group(1)
          gauss_lst.append(int(gauss_num.group(1)))
      if wer:
          wer_num = re.match(r"\%WER (\d+\.*\d+).*", i)
          #print wer_num.group(1)
          wer_lst.append(float(wer_num.group(1)))

      if train_time:
          train_time = re.match(r".*training.*total: (\d+) sec.*", i)
          #print train_time.group(1)
          train_time_lst.append(int(train_time.group(1)))

      if eval_time:
          eval_time = re.match(r".*evaluation.*total: (\d+) sec.*", i)
          #print eval_time.group(1)
          eval_time_lst.append(int(eval_time.group(1)))


#
#
print len(gauss_lst)
print len(train_time_lst)
print len(eval_time_lst)


fig = plt.figure(figsize=(8, 4))
ax = fig.add_subplot(111)
ax.set_xlabel('Gauss Num')
ax.set_ylabel('Time')
ax.plot(gauss_lst, train_time_lst, label="Train Time(sec)")
ax.plot(gauss_lst, eval_time_lst, label="Decode Time(sec)")
ax.grid('on')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# 39
# 39
# 39

# %%
fig = plt.figure(figsize=(8, 4))
ax = fig.add_subplot(111)
ax.set_xlabel('Gauss Num')
ax.set_ylabel('WER Value')
ax.plot(gauss_lst, wer_lst, label="WER Value")

ax.grid('on')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# def simple_print(y_label,value1_list,value1_label, value2_list, value2_label, step_list):
#     print "simple_print"
#     fig = plt.figure(figsize=(8, 4))
#     ax = fig.add_subplot(111)
#     ax.set_xlabel('Gauss Num')
#     #ax.set_ylabel(y_label)
#     ax.set_ylabel('Time')
#     ax.plot(step_list, value1_list, label=value1_label)
#     ax.plot(step_list, value2_list, label=value2_label)
#     ax.grid('on')
#     plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

filename = "exp_tr1.log"
path = "/Users/xuziqiang/Edinburgh/ASR/AutoSpchRcgntion/"
logfile = path+filename
with open(logfile, "r") as ins:
    loglist = []
    for line in ins:

        loglist.append(line)


import re
gaus_lst = []
leaf_lst = []
wer2_lst = []
# train_time_lst = []
# eval_time_lst = []

for i in loglist:
    title = re.match(r".*testing.*" ,i)
    #print title
    wer = re.match(r"\%WER.*", i)
#       train_time = re.match(r".*training.*", i)
#       eval_time = re.match(r".*evaluation.*", i)
    if title != None:
        leaf_gauss = re.match(r".*testing.*leaf: (\d+),.*number: (\d+).*", i)
        #print leaf_gauss.group(1),leaf_gauss.group(2)
        leaf_lst.append(int(leaf_gauss.group(1)))
        gaus_lst.append(int(leaf_gauss.group(2)))
          #gauss_lst.append(int(gauss_num.group(1)))
    if wer:
        wer_num = re.match(r"\%WER (\d+\.*\d+).*", i)
        #print wer_num.group(1)
        wer2_lst.append(float(wer_num.group(1)))

#       if train_time:
#           train_time = re.match(r".*training.*total: (\d+) sec.*", i)
#           #print train_time.group(1)
#           train_time_lst.append(int(train_time.group(1)))

#       if eval_time:
#           eval_time = re.match(r".*evaluation.*total: (\d+) sec.*", i)
#           #print eval_time.group(1)
#           eval_time_lst.append(int(eval_time.group(1)))


#
#
# print len(leaf_lst)
# print len(gaus_lst)
# print len(wer2_lst)
# print(train_time_lst)
# print(eval_time_lst)


# fig = plt.figure(figsize=(8, 4))
# ax = fig.add_subplot(111)
# ax.set_xlabel('Gauss Num')
# ax.set_ylabel('Time')
# ax.plot(gauss_lst, train_time_lst, label="Train Time(sec)")
# ax.plot(gauss_lst, eval_time_lst, label="Decode Time(sec)")
# ax.grid('on')
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
from __future__ import print_function

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
import time


def generateZ(X, Y):
    '''
    fill in the matrix of Z, by looking for exact (x, y)
    '''
    Z = np.zeros_like(X)

    #update Z matrix

    return Z


fig = plt.figure(figsize=(8, 4))
ax = fig.add_subplot(111, projection='3d')

#X should be leaf number list

leaf_array = np.array(leaf_lst)
#Y should be gauss number

gauss_array = np.array(gaus_lst)

X, Y = np.meshgrid(leaf_array, gauss_array)

#print(X) 
#print(Y) 

wer_array = np.array(wer2_lst)
Z, _ = np.meshgrid(wer_array,gauss_array)

#print(np.transpose(Z))
                  
# Set the z axis limits so they aren't recalculated each frame.
ax.set_zlim(0, 100)
ax.set_xlim(200, 5000)
ax.set_ylim(2000, 40000)
# # Begin plotting.
wframe = None
tstart = time.time()

if wframe:
     ax.collections.remove(wframe)

#     # Plot the new wireframe and pause briefly before continuing.
# Z = generateZ(X, Y)
wframe = ax.plot_wireframe(X, Y, np.transpose(Z), rstride=2, cstride=2)

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import random

def fun(x, y):
  return x**2 + y

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#x = y = np.arange(-3.0, 3.0, 0.05)
#X, Y = np.meshgrid(x, y)
#print(X)
#print(Y)
#zs = np.array([fun(x,y) for x,y in zip(np.ravel(X), np.ravel(Y))])
#Z = zs.reshape(X.shape)
#print(Z)
ax.plot_surface(X, Y, Z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Grab some test data.
#X, Y, Z = axes3d.get_test_data(0.05)

# Plot a basic wireframe.
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

plt.show()
